# %% [markdown]
# WRITE A PYTHON PROGRAM THAT LISTS ALL FILES IN A DIRECTORY
# AND CATEGORIZED THEM BY FILE EXTENSION

# %%
import os
files =[f for f in os.listdir('.') if os.path.isfile(f) ]
catergorized_files = {}
for file in files:
    if '.' in file:
        extension = file.split('.')[-1]
    
    else:
    
        extension = ''

    if extension not in catergorized_files:
        catergorized_files[extension] =[]
    catergorized_files[extension].append(file)
print(catergorized_files)
# Out:
# {'txt': ['sample.txt'], 'ipynb': ['U1_Q2_PATTERN.ipynb', 'U1_Q5.ipynb', 'U1_Q7.ipynb', 'U2_Q10.ipynb', 'U2_Q6.ipynb', 'U2_Q7.ipynb', 'U2_Q8.ipynb', 'U2_Q9.ipynb']}
